# %% [markdown]
# <a href="https://colab.research.google.com/github/DuarteMagano/Hello-Quantum-World/blob/main/tutorial_students_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# %pip install qiskit==2.1.2 pylatexenc
# %pip install qiskit-ibm-rutime
# %pip install qiskit[visualization]
